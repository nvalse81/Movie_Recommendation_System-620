# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler # for scaling
from sklearn.model_selection import train_test_split # for train test split
from sklearn.decomposition import PCA # for PCA

# %%
data = sns.load_dataset('diamonds') # Load the data
print(data.shape)
data.head()
# Out:
# (53940, 10)
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
data["cut"].value_counts() # categorical data
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
data["color"].value_counts() # categorical data
# Out:
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: color, dtype: int64

# %%
data["clarity"].value_counts() # categorical data
# Out:
# SI1     13065
# VS2     12258
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: clarity, dtype: int64

# %%
data["cut"] = data["cut"].replace({"Fair":0, "Good":1, "Very Good":2, "Premium":3, "Ideal":4}) # rename categorical data into numerical data
data["color"] = data["color"].replace({'D':0, 'E':1, 'F':2, 'G':3, 'H':4, 'I':5, 'J':6})
data["clarity"] = data["clarity"].replace({'IF':0, 'VVS1':1, 'VVS2':2, 'VS1':3, 'VS2':4, 'SI1':5, 'SI2':6, 'I1':7})

# %%
data.head()
# Out:
#    carat cut color clarity  depth  table  price     x     y     z
# 0   0.23   4     1       6   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21   3     1       5   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23   1     1       3   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29   3     5       4   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31   1     6       6   63.3   58.0    335  4.34  4.35  2.75

# %%
y = data["price"]
X = data.drop("price", axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

std = StandardScaler()
X_train_std = std.fit_transform(X_train)
X_test_std = std.transform(X_test)

# %% [markdown]
# ### Correlation:

# %%
df_train = pd.DataFrame(X_train_std, columns=['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z'])
df_train["price"] = y_train

corr = df_train.corr()
plt.figure(figsize = (12,10))

sns.heatmap(round(corr, 3), annot = True, vmin=-1, vmax=1, cmap="YlGnBu", linewidths=.5)
plt.grid(b=True, color='#f68c1f', alpha=0.1)
plt.show()
# Out:
# C:\Users\valse\AppData\Local\Temp\ipykernel_18912\2388152273.py:8: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, color='#f68c1f', alpha=0.1)

# %% [markdown]
# ## PCA:

# %%
pca = PCA(n_components = X_train_std.shape[1])
pca_data = pca.fit_transform(X_train_std)

percent_var_explained = pca.explained_variance_/(np.sum(pca.explained_variance_))
cumm_var_explained = np.cumsum(percent_var_explained)

plt.plot(cumm_var_explained)
plt.grid()
plt.xlabel("n_components")
plt.ylabel("% variance explained")
plt.show()

# %%
cumm_var_explained
# Out:
# array([0.46794816, 0.62410339, 0.76006614, 0.87016743, 0.94641894,
#        0.98631465, 0.99262445, 0.99829572, 1.        ])

# %%
pca.explained_variance_
# Out:
# array([4.21164495, 1.4054343 , 1.22369721, 0.99093785, 0.6862817 ,
#        0.35907092, 0.05678968, 0.05104286, 0.01533889])

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.9999999999999999

# %%
pca = PCA(n_components=6)
pca_train_data = pca.fit_transform(X_train_std)
pca_test_data = pca.transform(X_test_std)

# %% [markdown]
# ### Correlation after PCA:

# %%
df_train_pca = pd.DataFrame(pca_train_data)
df_train_pca["price"] = y_train

corr = df_train_pca.corr()
plt.figure(figsize = (12,10))

sns.heatmap(corr, annot = True, vmin=-1, vmax=1, cmap="YlGnBu", linewidths=.5)
plt.grid(b=True, color='#f68c1f', alpha=0.1)
plt.show()
# Out:
# C:\Users\valse\AppData\Local\Temp\ipykernel_18912\2354234762.py:8: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, color='#f68c1f', alpha=0.1)
